# %% [markdown]
# #Team Notebook - Mobility - car traffic in Hamburg
# ## API data: Traffic data cars (measured with infrared sensors)
#
# ---
#
#
# https://metaver.de/trefferanzeige?docuuid=2936465E-C045-4F5D-8614-24C3FBB522E2

# %% [markdown]
# #Procedure
# 1. Get a dataset of all Zählstellen
# 2. Get the corresponding observations for each Zählstelle

# %% [markdown]
# #1. Get dataset of all Zählstellen

# %%
import json
import pandas as pd
import requests
import numpy as np


#read the data from the web
response = requests.get("https://iot.hamburg.de/v1.1/Datastreams?$filter=properties/serviceName eq 'HH_STA_AutomatisierteVerkehrsmengenerfassung' and properties/layerName eq 'Anzahl_Kfz_Zaehlstelle_1-Tag'&$top=500")
  #--> API Status Code 200: Everything went okay
print(response.json())
# Out:
# {'value': [{'description': 'Die Anzahl der von der Infrarotkamera erfassten Kfz wird für ein 1-Tag-Intervall aufsummiert.', '@iot.id': 13600, 'name': 'Kfz-Aufkommen an Verkehrszählstelle 0314962 im 1-Tag-Intervall', 'observationType': 'http://defs.opengis.net/elda-common/ogc-def/resource?uri=http://www.opengis.net/def/ogc-om/OM_CountObservation', 'observedArea': {'type': 'Point', 'coordinates': [10.057635, 53.579578]}, 'phenomenonTime': '2020-10-31T23:00:00.000Z/2021-06-20T21:59:59.000Z', 'properties': {'metadata': 'https://registry.gdi-de.org/id/de.hh/03957ed9-5fc4-48a5-997e-e46c8c207c8f', 'layerName': 'Anzahl_Kfz_Zaehlstelle_1-Tag', 'ownerData': 'Freie und Hansestadt Hamburg', 'serviceName': 'HH_STA_AutomatisierteVerkehrsmengenerfassung', 'resultNature': 'processed', 'infoLastUpdate': '2021-01-22T14:36:35.705Z', 'mediaMonitored': 'transport', 'statisticalUnit': 'count', 'aggregateDuration': 'P1D', 'aggregateSource.Datastream@iot.id': 13598, 'aggregateSource.Datastream@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13598)'}, 'resultTime': '2021-01-23T01:27:30.375Z/2021-06-21T01:24:28.293Z', '@iot.selfLink': 'https://iot.hamburg.de/v1.1/Datastreams(13600)', 'unitOfMeasurement': {'name': 'Anzahl', 'symbol': None, 'definition': None}, 'Thing@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13600)/Thing', 'Observations@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13600)/Observations', 'ObservedProperty@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13600)/ObservedProperty', 'Sensor@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13600)/Sensor'}, {'description': 'Die Anzahl der von der Infrarotkamera erfassten Kfz wird für ein 1-Tag-Intervall aufsummiert.', '@iot.id': 13596, 'name': 'Kfz-Aufkommen an Verkehrszählstelle 0314960 im 1-Tag-Intervall', 'observationType': 'http://defs.opengis.net/elda-common/ogc-def/resource?uri=http://www.opengis.net/def/ogc-om/OM_CountObservation', 'observedArea': {'type': 'Point', 'coordinates': [10.057484, 53.579579]}, 'phenomenonTime': '2020-10-31T23:00:00.000Z/2021-06-20T21:59:59.000Z', 'properties': {'metadata': 'https://registry.gdi-de.org/id/de.hh/03957ed9-5fc4-48a5-997e-e46c8c207c8f', 'layerName': 'Anzahl_Kfz_Zaehlstelle_1-Tag', 'ownerData': 'Freie und Hansestadt Hamburg', 'serviceName': 'HH_STA_AutomatisierteVerkehrsmengenerfassung', 'resultNature': 'processed', 'infoLastUpdate': '2021-01-22T14:36:30.381Z', 'mediaMonitored': 'transport', 'statisticalUnit': 'count', 'aggregateDuration': 'P1D', 'aggregateSource.Datastream@iot.id': 13594, 'aggregateSource.Datastream@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13594)'}, 'resultTime': '2021-02-02T17:29:59.993Z/2021-06-21T01:24:28.328Z', '@iot.selfLink': 'https://iot.hamburg.de/v1.1/Datastreams(13596)', 'unitOfMeasurement': {'name': 'Anzahl', 'symbol': None, 'definition': None}, 'Thing@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13596)/Thing', 'Observations@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13596)/Observations', 'ObservedProperty@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13596)/ObservedProperty', 'Sensor@iot.navigationLink': 'https://iot.hamburg.de/v1.1/Datastreams(13596)/Sensor'}, {'description': 'Die Anzahl der von der Infrarotkamera erfassten Kfz wird für ein 1-Tag-Intervall aufsummiert.', '@iot.id': 14392, 'name': 'Kfz-Aufkommen an Verkehrszählstelle 0267951 im 1-Tag-Intervall', 'observationType': 'http://defs.opengis.net/elda-common/ogc-def/resource?uri=http://www.opengis.net/def/ogc-om/OM_CountObservation', 'observedArea': {'type': 'Point', 'coordinates': [9.934472, 53.582967]}, 'phenomenonTime': '2020-10-31T23:00:00.000Z/2021-06-20T21:59:59.000Z', 'properties': {'metadata': 'https://registry.gdi-de.org/id/de.hh/03957ed9-5fc4-48a5-997e-e46c8c207c8f', 'layerName': 'Anzahl_Kfz_Zaehlstelle_1-Tag', 'ownerData': 'Freie und Hansestadt Hamburg', 'serviceName': 'HH_STA_AutomatisierteVerkehrsmeng ...

# %% [markdown]
# API Status Codes
#
# Status codes are returned with every request that is made to a web server. Status codes indicate information about what happened with a request. Here are some codes that are relevant to GET requests:
#
#     200: Everything went okay, and the result has been returned (if any).
#     301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#     400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
#     401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
#     403: The resource you’re trying to access is forbidden: you don’t have the right permissions to see it.
#     404: The resource you tried to access wasn’t found on the server.
#     503: The server is not ready to handle the request.
#
# You might notice that all of the status codes that begin with a ‘4’ indicate some sort of error. The first number of status codes indicate their categorization. This is useful — you can know that if your status code starts with a ‘2’ it was successful and if it starts with a ‘4’ or ‘5’ there was an error.

# %% [markdown]
# ## Turn the JSON response in usable data

# %%
#Extract the data from the the response object
betterdata=response.json()
  #type(betterdata)
  #--> type: dict


#only select the data, which are under the heading "value" and convert this to a pandas dataframe
test = betterdata["value"]
  #type(test)
  #--> type: List
  
firstdataframe = pd.DataFrame(test)
firstdataframe.columns

#save Zählstellen IDs in a panda series for easier use later
iotids = firstdataframe["@iot.id"]

#save Zählstellen Download-Links in a panda series for easier use later
Links = firstdataframe["Observations@iot.navigationLink"]

# %%
type(betterdata)
# Out:
# dict

# %%
df = pd.Datafram.from_dict(betterdata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-cdca48f0182d> in <module>()
# ----> 1 df = pd.Datafram.from_dict(betterdata)
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'Datafram'

# %% [markdown]
# #2. Loop through the links of all "Zählstellen" to receive a dataset of the nr. of vehicles for every day/every "Zählstelle"

# %%
#first every Zählstelle is assigned a number (Sequence) to use in the loop (e.g. 493 Zählstellen --> sequence of 0 to 492)
NoZaehlstellen = len(Links.index)

Sequence = np.array(range(0,NoZaehlstellen))

# create a list for the results
ListofAll = list()


for x in Sequence:
  #by default only the first 100 observations for this "Zählstelle" will be shown, therefore we expand the results to max 600
  Testlink = Links[x]+"?$top=600"
  #read the data from the web
  Fall = requests.get(Testlink)
    #--> API Status Code 200: Everything went okay
  #Extract the data from the the Fall-object
  FallData = Fall.json()
  #only select the data, which are under the heading "value" and convert this to a pandas dataframe
  FallDataValue = FallData["value"]
  FallDataFrame = pd.DataFrame(FallDataValue)
  #New column is created with the IDs for each Zählstelle
  FallDataFrame["ZaehlstelleID"] = iotids[x]
  #all observations from all Zählstellen are appended to the final list
  ListofAll.append(FallDataFrame)

# %%
print(ListofAll)
# Out:
# [       @iot.id  ... ZaehlstelleID
# 0     51218835  ...         13600
# 1     51493102  ...         13600
# 2     51730740  ...         13600
# 3     51836486  ...         13600
# 4     51836603  ...         13600
# ..         ...  ...           ...
# 120  149616436  ...         13600
# 121  150688831  ...         13600
# 122  152467731  ...         13600
# 123  154042209  ...         13600
# 124  155510408  ...         13600
#
# [125 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51218837  ...         13596
# 1     51493103  ...         13596
# 2     51730741  ...         13596
# 3     51836604  ...         13596
# 4     51836487  ...         13596
# ..         ...  ...           ...
# 120  149616437  ...         13596
# 121  150688832  ...         13596
# 122  152467732  ...         13596
# 123  154042210  ...         13596
# 124  155510409  ...         13596
#
# [125 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220438  ...         14392
# 1     51495503  ...         14392
# 2     51733078  ...         14392
# 3     51844205  ...         14392
# 4     51838168  ...         14392
# ..         ...  ...           ...
# 126  149616654  ...         14392
# 127  150695816  ...         14392
# 128  152474987  ...         14392
# 129  154049545  ...         14392
# 130  155517735  ...         14392
#
# [131 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217146  ...         13044
# 1     51491491  ...         13044
# 2     51729207  ...         13044
# 3     51834800  ...         13044
# 4     51835054  ...         13044
# ..         ...  ...           ...
# 228  149616455  ...         13044
# 229  150685409  ...         13044
# 230  152464318  ...         13044
# 231  154038542  ...         13044
# 232  155506611  ...         13044
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221957  ...         14756
# 1     51496311  ...         14756
# 2     51734027  ...         14756
# 3     51839810  ...         14756
# 4     51839549  ...         14756
# ..         ...  ...           ...
# 228  149616864  ...         14756
# 229  150699935  ...         14756
# 230  152478980  ...         14756
# 231  154053650  ...         14756
# 232  155522005  ...         14756
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221203  ...         14568
# 1     51495812  ...         14568
# 2     51733389  ...         14568
# 3     51838462  ...         14568
# 4     51838732  ...         14568
# ..         ...  ...           ...
# 120  149568650  ...         14568
# 121  150697135  ...         14568
# 122  152476283  ...         14568
# 123  154050909  ...         14568
# 124  155518971  ...         14568
#
# [125 rows x 9 columns], Empty DataFrame
# Columns: [ZaehlstelleID]
# Index: [],        @iot.id  ... ZaehlstelleID
# 0     51221959  ...         14760
# 1     51496321  ...         14760
# 2     51734039  ...         14760
# 3     51839572  ...         14760
# 4     51839563  ...         14760
# ..         ...  ...           ...
# 228  149616297  ...         14760
# 229  150699949  ...         14760
# 230  152479011  ...         14760
# 231  154053655  ...         14760
# 232  155522018  ...         14760
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220692  ...         14464
# 1     51495624  ...         14464
# 2     51733221  ...         14464
# 3     51844372  ...         14464
# 4     51838309  ...         14464
# ..         ...  ...           ...
# 220  149616410  ...         14464
# 221  150696270  ...         14464
# 222  152475366  ...         14464
# 223  154049883  ...         14464
# 224  155518302  ...         14464
#
# [225 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221762  ...         14708
# 1     51496224  ...         14708
# 2     51733945  ...         14708
# 3     51839368  ...         14708
# 4     51839439  ...         14708
# ..         ...  ...           ...
# 214  149568419  ...         14708
# 215  150699450  ...         14708
# 216  152478563  ...         14708
# 217  154053179  ...         14708
# 218  155521133  ...         14708
#
# [219 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51218278  ...         13528
# 1    51492507  ...         13528
# 2    51730487  ...         13528
# 3    51835958  ...         13528
# 4    51836368  ...         13528
# ..        ...  ...           ...
# 93  148720987  ...         13528
# 94  150695716  ...         13528
# 95  152474877  ...         13528
# 96  154049459  ...         13528
# 97  155517679  ...         13528
#
# [98 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51841199  ...         13324
# 1     51840974  ...         13324
# 2     51835480  ...         13324
# 3     51835306  ...         13324
# 4     51835473  ...         13324
# ..         ...  ...           ...
# 228  149616572  ...         13324
# 229  150687036  ...         13324
# 230  152465587  ...         13324
# 231  154040206  ...         13324
# 232  155508415  ...         13324
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221795  ...         14288
# 1     51494783  ...         14288
# 2     51837929  ...         14288
# 3     51837788  ...         14288
# 4     51843947  ...         14288
# ..         ...  ...           ...
# 216  149616716  ...         14288
# 217  150694914  ...         14288
# 218  152474006  ...         14288
# 219  154048542  ...         14288
# 220  155516816  ...         14288
#
# [221 rows x 9 columns],      @iot.id  ... ZaehlstelleID
# 0   51217646  ...         13292
# 1   51491993  ...         13292
# 2   51729613  ...         13292
# 3   51840924  ...         13292
# 4   51835430  ...         13292
# ..       ...  ...           ...
# 92  53950285  ...         13292
# 93  54159192  ...         13292
# 94  54330454  ...         13292
# 95  62353587  ...         13292
# 96  62417066  ...         13292
#
# [97 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51841189  ...         13316
# 1     51835461  ...         13316
# 2     51835468  ...         13316
# 3     51835300  ...         13316
# 4     51840956  ...         13316
# ..         ...  ...           ...
# 227  149616574  ...         13316
# 228  150687020  ...         13316
# 229  152465556  ...         13316
# 230  154040124  ...         13316
# 231  155508337  ...         13316
#
# [232 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51222084  ...         14788
# 1     51496380  ...         14788
# 2     51734093  ...         14788
# 3     51839655  ...         14788
# 4     51839947  ...         14788
# ..         ...  ...           ...
# 228  149616240  ...         14788
# 229  150700326  ...         14788
# 230  152479407  ...         14788
# 231  154053920  ...         14788
# 232  155522285  ...         14788
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51217347  ...         13136
# 1    51835166  ...         13136
# 2    51835186  ...         13136
# 3    51834981  ...         13136
# 4    51840611  ...         13136
# ..        ...  ...           ...
# 176  73459919  ...         13136
# 177  73677394  ...         13136
# 178  73894472  ...         13136
# 179  74110466  ...         13136
# 180  74321542  ...         13136
#
# [181 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220598  ...         14436
# 1     51495590  ...         14436
# 2     51733194  ...         14436
# 3     51838247  ...         14436
# 4     51838130  ...         14436
# ..         ...  ...           ...
# 228  149616642  ...         14436
# 229  150696139  ...         14436
# 230  152475237  ...         14436
# 231  154049783  ...         14436
# 232  155518052  ...         14436
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51222146  ...         14812
# 1     51496408  ...         14812
# 2     51734122  ...         14812
# 3     51839722  ...         14812
# 4     51839688  ...         14812
# ..         ...  ...           ...
# 228  149616089  ...         14812
# 229  150700539  ...         14812
# 230  152479608  ...         14812
# 231  154054122  ...         14812
# 232  155522533  ...         14812
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219151  ...         13724
# 1     51493391  ...         13724
# 2     51731019  ...         13724
# 3     51836833  ...         13724
# 4     51836618  ...         13724
# ..         ...  ...           ...
# 194  149616366  ...         13724
# 195  150690415  ...         13724
# 196  152469076  ...         13724
# 197  154043589  ...         13724
# 198  155511727  ...         13724
#
# [199 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51843552  ...         13972
# 1     51837077  ...         13972
# 2     51837285  ...         13972
# 3     51837202  ...         13972
# 4     51843072  ...         13972
# ..         ...  ...           ...
# 225  149616639  ...         13972
# 226  150692811  ...         13972
# 227  152471449  ...         13972
# 228  154045949  ...         13972
# 229  155514564  ...         13972
#
# [230 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51491752  ...         13164
# 1     51844752  ...         13164
# 2     51835037  ...         13164
# 3     51835228  ...         13164
# 4     51840699  ...         13164
# ..         ...  ...           ...
# 228  149616323  ...         13164
# 229  150686040  ...         13164
# 230  152464867  ...         13164
# 231  154039141  ...         13164
# 232  155507449  ...         13164
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51494445  ...         14144
# 1     51732006  ...         14144
# 2     51843592  ...         14144
# 3     51837683  ...         14144
# 4     51837635  ...         14144
# ..         ...  ...           ...
# 228  149616315  ...         14144
# 229  150693932  ...         14144
# 230  152472662  ...         14144
# 231  154047337  ...         14144
# 232  155515643  ...         14144
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493669  ...         13840
# 1     51731404  ...         13840
# 2     51837033  ...         13840
# 3     51836824  ...         13840
# 4     51836962  ...         13840
# ..         ...  ...           ...
# 228  149616253  ...         13840
# 229  150691830  ...         13840
# 230  152470496  ...         13840
# 231  154045172  ...         13840
# 232  155513517  ...         13840
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51837688  ...         14164
# 1    51837744  ...         14164
# 2    51843743  ...         14164
# 3    51843966  ...         14164
# 4    51849248  ...         14164
# ..        ...  ...           ...
# 86  149616411  ...         14164
# 87  150694002  ...         14164
# 88  152472847  ...         14164
# 89  154047469  ...         14164
# 90  155515798  ...         14164
#
# [91 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219426  ...         13892
# 1     51837069  ...         13892
# 2     51836923  ...         13892
# 3     51842836  ...         13892
# 4     51848325  ...         13892
# ..         ...  ...           ...
# 228  149616861  ...         13892
# 229  150692223  ...         13892
# 230  152471015  ...         13892
# 231  154045491  ...         13892
# 232  155513942  ...         13892
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219749  ...         14000
# 1     51494111  ...         14000
# 2     51731659  ...         14000
# 3     51837328  ...         14000
# 4     51837255  ...         14000
# ..         ...  ...           ...
# 228  149615194  ...         14000
# 229  150692915  ...         14000
# 230  152471529  ...         14000
# 231  154046118  ...         14000
# 232  155514755  ...         14000
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217797  ...         13404
# 1     51492129  ...         13404
# 2     51729799  ...         13404
# 3     51835655  ...         13404
# 4     51835435  ...         13404
# ..         ...  ...           ...
# 162  148726000  ...         13404
# 163  150700966  ...         13404
# 164  152480112  ...         13404
# 165  154054563  ...         13404
# 166  155523064  ...         13404
#
# [167 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51837258  ...         13996
# 1     51837329  ...         13996
# 2     51837107  ...         13996
# 3     51843613  ...         13996
# 4     51843148  ...         13996
# ..         ...  ...           ...
# 228  149615353  ...         13996
# 229  150692916  ...         13996
# 230  152471530  ...         13996
# 231  154046119  ...         13996
# 232  155514756  ...         13996
#
# [233 rows x 9 columns], Empty DataFrame
# Columns: [ZaehlstelleID]
# Index: [],        @iot.id  ... ZaehlstelleID
# 0     51219725  ...         13984
# 1     51494098  ...         13984
# 2     51731634  ...         13984
# 3     51837085  ...         13984
# 4     51837301  ...         13984
# ..         ...  ...           ...
# 228  145265907  ...         13984
# 229  150692834  ...         13984
# 230  152471482  ...         13984
# 231  154045961  ...         13984
# 232  155514618  ...         13984
#
# [233 rows x 9 columns],      @iot.id  ... ZaehlstelleID
# 0   51219506  ...         13916
# 1   51493960  ...         13916
# 2   51836957  ...         13916
# 3   51837092  ...         13916
# 4   51842904  ...         13916
# 5   51848547  ...         13916
# 6   51848381  ...         13916
# 7   51854237  ...         13916
# 8   51853903  ...         13916
# 9   51859311  ...         13916
# 10  51859332  ...         13916
# 11  51961713  ...         13916
# 12  52207219  ...         13916
# 13  52428935  ...         13916
# 14  53578518  ...         13916
# 15  53593007  ...         13916
# 16  53602484  ...         13916
# 17  53607092  ...         13916
# 18  53611525  ...         13916
# 19  53616104  ...         13916
# 20  53620662  ...         13916
# 21  53624721  ...         13916
# 22  53629376  ...         13916
# 23  53633966  ...         13916
# 24  53638054  ...         13916
# 25  53641942  ...         13916
# 26  53642589  ...         13916
# 27  53647006  ...         13916
# 28  53646496  ...         13916
# 29  53651350  ...         13916
# 30  53650796  ...         13916
# 31  53655760  ...         13916
# 32  53656305  ...         13916
# 33  53660119  ...         13916
# 34  53660369  ...         13916
# 35  53664753  ...         13916
# 36  53668457  ...         13916
# 37  53671493  ...         13916
# 38  53672252  ...         13916
# 39  53673122  ...         13916
# 40  53675969  ...         13916
# 41  53679690  ...         13916
# 42  53676894  ...         13916
# 43  53680374  ...         13916
# 44  53683034  ...         13916
# 45  53683582  ...         13916
# 46  53685897  ...         13916
# 47  53687520  ...         13916
# 48  53686878  ...         13916
# 49  53690204  ...         13916
# 50  53690635  ...         13916
# 51  53693442  ...         13916
# 52  53696981  ...         13916
# 53  62354496  ...         13916
#
# [54 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221861  ...         14732
# 1     51496260  ...         14732
# 2     51733980  ...         14732
# 3     51839708  ...         14732
# 4     51839449  ...         14732
# ..         ...  ...           ...
# 120  149616811  ...         14732
# 121  150699676  ...         14732
# 122  152478769  ...         14732
# 123  154053472  ...         14732
# 124  155521677  ...         14732
#
# [125 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493996  ...         13924
# 1     51843398  ...         13924
# 2     51837170  ...         13924
# 3     51837109  ...         13924
# 4     51836975  ...         13924
# ..         ...  ...           ...
# 228  149615437  ...         13924
# 229  150692445  ...         13924
# 230  152471154  ...         13924
# 231  154045652  ...         13924
# 232  155514133  ...         13924
#
# [233 rows x 9 columns],      @iot.id  ... ZaehlstelleID
# 0   51221371  ...         14592
# 1   51495876  ...         14592
# 2   51733477  ...         14592
# 3   51844721  ...         14592
# 4   51838999  ...         14592
# ..       ...  ...           ...
# 95  54334091  ...         14592
# 96  54624550  ...         14592
# 97  54924442  ...         14592
# 98  54463606  ...         14592
# 99  68389199  ...         14592
#
# [100 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51729800  ...         13400
# 1     51835436  ...         13400
# 2     51835749  ...         13400
# 3     51835656  ...         13400
# 4     51841197  ...         13400
# ..         ...  ...           ...
# 228  149616587  ...         13400
# 229  150687460  ...         13400
# 230  152466043  ...         13400
# 231  154040706  ...         13400
# 232  155508961  ...         13400
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221230  ...         14576
# 1     51495832  ...         14576
# 2     51733395  ...         14576
# 3     51844685  ...         14576
# 4     51838853  ...         14576
# ..         ...  ...           ...
# 120  149616813  ...         14576
# 121  150697291  ...         14576
# 122  152476457  ...         14576
# 123  154051042  ...         14576
# 124  155519107  ...         14576
#
# [125 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217503  ...         13204
# 1     51491840  ...         13204
# 2     51729475  ...         13204
# 3     51840936  ...         13204
# 4     51835274  ...         13204
# ..         ...  ...           ...
# 228  149615848  ...         13204
# 229  150686325  ...         13204
# 230  152465072  ...         13204
# 231  154039367  ...         13204
# 232  155507668  ...         13204
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51219988  ...         14104
# 1    51494315  ...         14104
# 2    51731872  ...         14104
# 3    51962132  ...         14104
# 4    52207790  ...         14104
# ..        ...  ...           ...
# 84  149616905  ...         14104
# 85  150693497  ...         14104
# 86  152472258  ...         14104
# 87  154046833  ...         14104
# 88  155515410  ...         14104
#
# [89 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217510  ...         13200
# 1     51729476  ...         13200
# 2     51840781  ...         13200
# 3     51835273  ...         13200
# 4     51835275  ...         13200
# ..         ...  ...           ...
# 228  149615873  ...         13200
# 229  150686327  ...         13200
# 230  152465073  ...         13200
# 231  154039368  ...         13200
# 232  155507669  ...         13200
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219594  ...         13932
# 1     51494019  ...         13932
# 2     51731556  ...         13932
# 3     51837122  ...         13932
# 4     51837190  ...         13932
# ..         ...  ...           ...
# 228  149568754  ...         13932
# 229  150692532  ...         13932
# 230  152471212  ...         13932
# 231  154045731  ...         13932
# 232  155514256  ...         13932
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51492188  ...         13432
# 1     51729932  ...         13432
# 2     51835504  ...         13432
# 3     51835830  ...         13432
# 4     51841323  ...         13432
# ..         ...  ...           ...
# 228  149616468  ...         13432
# 229  150687679  ...         13432
# 230  152466340  ...         13432
# 231  154040997  ...         13432
# 232  155509258  ...         13432
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217052  ...         12992
# 1     51491354  ...         12992
# 2     51728995  ...         12992
# 3     51834951  ...         12992
# 4     51834668  ...         12992
# ..         ...  ...           ...
# 229  149616691  ...         12992
# 230  150685119  ...         12992
# 231  152464090  ...         12992
# 232  154038325  ...         12992
# 233  155506340  ...         12992
#
# [234 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220546  ...         14428
# 1     51495573  ...         14428
# 2     51733178  ...         14428
# 3     51838266  ...         14428
# 4     51838097  ...         14428
# ..         ...  ...           ...
# 228  149616234  ...         14428
# 229  150696057  ...         14428
# 230  152475166  ...         14428
# 231  154049731  ...         14428
# 232  155517920  ...         14428
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221920  ...         14744
# 1     51496288  ...         14744
# 2     51734002  ...         14744
# 3     51964290  ...         14744
# 4     52209966  ...         14744
# ..         ...  ...           ...
# 155  149616908  ...         14744
# 156  150699810  ...         14744
# 157  152478899  ...         14744
# 158  154053542  ...         14744
# 159  155521834  ...         14744
#
# [160 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493609  ...         13824
# 1     51731344  ...         13824
# 2     51836978  ...         13824
# 3     51836802  ...         13824
# 4     51836936  ...         13824
# ..         ...  ...           ...
# 228  149616244  ...         13824
# 229  150691576  ...         13824
# 230  152469952  ...         13824
# 231  154044509  ...         13824
# 232  155512851  ...         13824
#
# [233 rows x 9 columns],      @iot.id  ... ZaehlstelleID
# 0   51491994  ...         13288
# 1   51729614  ...         13288
# 2   51835271  ...         13288
# 3   51835431  ...         13288
# 4   51846972  ...         13288
# ..       ...  ...           ...
# 92  53655801  ...         13288
# 93  53676932  ...         13288
# 94  53679726  ...         13288
# 95  52205147  ...         13288
# 96  53683073  ...         13288
#
# [97 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51836939  ...         13784
# 1     51836892  ...         13784
# 2     51836739  ...         13784
# 3     51842780  ...         13784
# 4     51842622  ...         13784
# ..         ...  ...           ...
# 228  149616614  ...         13784
# 229  150691023  ...         13784
# 230  152469706  ...         13784
# 231  154044266  ...         13784
# 232  155512539  ...         13784
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217217  ...         13072
# 1     51491529  ...         13072
# 2     51729296  ...         13072
# 3     51840703  ...         13072
# 4     51834868  ...         13072
# ..         ...  ...           ...
# 228  149616298  ...         13072
# 229  150699951  ...         13072
# 230  152479012  ...         13072
# 231  154053656  ...         13072
# 232  155522019  ...         13072
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51220002  ...         14108
# 1    51494332  ...         14108
# 2    51731892  ...         14108
# 3    51962150  ...         14108
# 4    52207815  ...         14108
# ..        ...  ...           ...
# 84  149616904  ...         14108
# 85  150693575  ...         14108
# 86  152472299  ...         14108
# 87  154046963  ...         14108
# 88  155515423  ...         14108
#
# [89 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51491792  ...         13180
# 1     51729448  ...         13180
# 2     51835245  ...         13180
# 3     51835058  ...         13180
# 4     51862953  ...         13180
# ..         ...  ...           ...
# 228  149616304  ...         13180
# 229  150686148  ...         13180
# 230  152464940  ...         13180
# 231  154039218  ...         13180
# 232  155507529  ...         13180
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219481  ...         13912
# 1     51493938  ...         13912
# 2     51837081  ...         13912
# 3     51836945  ...         13912
# 4     51842878  ...         13912
# ..         ...  ...           ...
# 206  149616582  ...         13912
# 207  150692317  ...         13912
# 208  152471084  ...         13912
# 209  154045580  ...         13912
# 210  155514040  ...         13912
#
# [211 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217294  ...         13124
# 1     51491616  ...         13124
# 2     51729343  ...         13124
# 3     51834957  ...         13124
# 4     51835162  ...         13124
# ..         ...  ...           ...
# 228  149616305  ...         13124
# 229  150685742  ...         13124
# 230  152464622  ...         13124
# 231  154038888  ...         13124
# 232  155507045  ...         13124
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51729344  ...         13120
# 1     51840777  ...         13120
# 2     51835140  ...         13120
# 3     51834958  ...         13120
# 4     51835163  ...         13120
# ..         ...  ...           ...
# 228  149616312  ...         13120
# 229  150685743  ...         13120
# 230  152464623  ...         13120
# 231  154038889  ...         13120
# 232  155507046  ...         13120
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217431  ...         13168
# 1     51491751  ...         13168
# 2     51729413  ...         13168
# 3     51840870  ...         13168
# 4     51835221  ...         13168
# ..         ...  ...           ...
# 224  149616321  ...         13168
# 225  150686039  ...         13168
# 226  152464866  ...         13168
# 227  154039140  ...         13168
# 228  155507448  ...         13168
#
# [229 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219145  ...         13712
# 1     51731014  ...         13712
# 2     51836828  ...         13712
# 3     51836747  ...         13712
# 4     51836613  ...         13712
# ..         ...  ...           ...
# 194  149616339  ...         13712
# 195  150690411  ...         13712
# 196  152469072  ...         13712
# 197  154043585  ...         13712
# 198  155511717  ...         13712
#
# [199 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219196  ...         13744
# 1     51493440  ...         13744
# 2     51731075  ...         13744
# 3     51836809  ...         13744
# 4     51836661  ...         13744
# ..         ...  ...           ...
# 194  149616362  ...         13744
# 195  150690670  ...         13744
# 196  152469384  ...         13744
# 197  154043837  ...         13744
# 198  155512048  ...         13744
#
# [199 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220068  ...         14180
# 1     51494540  ...         14180
# 2     51732081  ...         14180
# 3     51837735  ...         14180
# 4     51837516  ...         14180
# ..         ...  ...           ...
# 228  149616400  ...         14180
# 229  150694102  ...         14180
# 230  152473016  ...         14180
# 231  154047607  ...         14180
# 232  155515919  ...         14180
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220074  ...         14184
# 1     51837739  ...         14184
# 2     51837781  ...         14184
# 3     51837521  ...         14184
# 4     51843990  ...         14184
# ..         ...  ...           ...
# 228  149616408  ...         14184
# 229  150694105  ...         14184
# 230  152473019  ...         14184
# 231  154047611  ...         14184
# 232  155515922  ...         14184
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217992  ...         13480
# 1     51492274  ...         13480
# 2     51841634  ...         13480
# 3     51836103  ...         13480
# 4     51835716  ...         13480
# ..         ...  ...           ...
# 228  149616152  ...         13480
# 229  150688030  ...         13480
# 230  152466633  ...         13480
# 231  154041291  ...         13480
# 232  155509565  ...         13480
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217993  ...         13476
# 1     51733317  ...         13476
# 2     51841635  ...         13476
# 3     51835717  ...         13476
# 4     51836138  ...         13476
# ..         ...  ...           ...
# 228  149616172  ...         13476
# 229  150688031  ...         13476
# 230  152466634  ...         13476
# 231  154041292  ...         13476
# 232  155509566  ...         13476
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217629  ...         13276
# 1     51491978  ...         13276
# 2     51835247  ...         13276
# 3     51835413  ...         13276
# 4     51835423  ...         13276
# ..         ...  ...           ...
# 228  149616295  ...         13276
# 229  150686866  ...         13276
# 230  152465444  ...         13276
# 231  154039920  ...         13276
# 232  155508219  ...         13276
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51217346  ...         13132
# 1    51491667  ...         13132
# 2    51729369  ...         13132
# 3    51840799  ...         13132
# 4    51834980  ...         13132
# ..        ...  ...           ...
# 176  73459918  ...         13132
# 177  73677393  ...         13132
# 178  73894471  ...         13132
# 179  74110465  ...         13132
# 180  74321539  ...         13132
#
# [181 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51494050  ...         13944
# 1     51731593  ...         13944
# 2     51837150  ...         13944
# 3     51837221  ...         13944
# 4     51843219  ...         13944
# ..         ...  ...           ...
# 227  149616373  ...         13944
# 228  150692623  ...         13944
# 229  152471315  ...         13944
# 230  154045818  ...         13944
# 231  155514361  ...         13944
#
# [232 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217175  ...         13052
# 1     51491506  ...         13052
# 2     51729256  ...         13052
# 3     51840670  ...         13052
# 4     51835096  ...         13052
# ..         ...  ...           ...
# 228  149568607  ...         13052
# 229  150685477  ...         13052
# 230  152464411  ...         13052
# 231  154038650  ...         13052
# 232  155506768  ...         13052
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217134  ...         13032
# 1     51729171  ...         13032
# 2     51835052  ...         13032
# 3     51835042  ...         13032
# 4     51834780  ...         13032
# ..         ...  ...           ...
# 229  149616419  ...         13032
# 230  150685356  ...         13032
# 231  152464289  ...         13032
# 232  154038519  ...         13032
# 233  155506572  ...         13032
#
# [234 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217563  ...         13232
# 1     51491912  ...         13232
# 2     51729525  ...         13232
# 3     51841017  ...         13232
# 4     51835325  ...         13232
# ..         ...  ...           ...
# 228  149616492  ...         13232
# 229  150686594  ...         13232
# 230  152465277  ...         13232
# 231  154039717  ...         13232
# 232  155507989  ...         13232
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51491952  ...         13256
# 1    51841079  ...         13256
# 2    51835380  ...         13256
# 3    51835204  ...         13256
# 4    51835384  ...         13256
# ..        ...  ...           ...
# 192  90255186  ...         13256
# 193  91914428  ...         13256
# 194  93151009  ...         13256
# 195  94747233  ...         13256
# 196  96108520  ...         13256
#
# [197 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51835354  ...         13240
# 1    51835362  ...         13240
# 2    51835178  ...         13240
# 3    51841065  ...         13240
# 4    51840802  ...         13240
# ..        ...  ...           ...
# 192  90254756  ...         13240
# 193  91914368  ...         13240
# 194  93150922  ...         13240
# 195  94747145  ...         13240
# 196  96108468  ...         13240
#
# [197 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217612  ...         13268
# 1     51491961  ...         13268
# 2     51729571  ...         13268
# 3     51840857  ...         13268
# 4     51835395  ...         13268
# ..         ...  ...           ...
# 228  149616462  ...         13268
# 229  150686767  ...         13268
# 230  152465363  ...         13268
# 231  154039814  ...         13268
# 232  155508157  ...         13268
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217147  ...         13040
# 1     51729209  ...         13040
# 2     51834801  ...         13040
# 3     51835072  ...         13040
# 4     51840497  ...         13040
# ..         ...  ...           ...
# 228  149616458  ...         13040
# 229  150685410  ...         13040
# 230  152464319  ...         13040
# 231  154038543  ...         13040
# 232  155506613  ...         13040
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217738  ...         13380
# 1     51492088  ...         13380
# 2     51729725  ...         13380
# 3     51835635  ...         13380
# 4     51835393  ...         13380
# ..         ...  ...           ...
# 228  149616551  ...         13380
# 229  150687313  ...         13380
# 230  152465832  ...         13380
# 231  154040481  ...         13380
# 232  155508726  ...         13380
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51491962  ...         13264
# 1     51841102  ...         13264
# 2     51840960  ...         13264
# 3     51835218  ...         13264
# 4     51835396  ...         13264
# ..         ...  ...           ...
# 228  149616465  ...         13264
# 229  150686768  ...         13264
# 230  152465364  ...         13264
# 231  154039815  ...         13264
# 232  155508158  ...         13264
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220073  ...         14188
# 1     51494542  ...         14188
# 2     51732083  ...         14188
# 3     51837520  ...         14188
# 4     51837738  ...         14188
# ..         ...  ...           ...
# 228  149616406  ...         14188
# 229  150694104  ...         14188
# 230  152473018  ...         14188
# 231  154047609  ...         14188
# 232  155515921  ...         14188
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220094  ...         14196
# 1     51494562  ...         14196
# 2     51732114  ...         14196
# 3     51837545  ...         14196
# 4     51837796  ...         14196
# ..         ...  ...           ...
# 228  149616403  ...         14196
# 229  150694177  ...         14196
# 230  152473140  ...         14196
# 231  154047702  ...         14196
# 232  155515953  ...         14196
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217977  ...         13472
# 1     51492259  ...         13472
# 2     51836117  ...         13472
# 3     51835661  ...         13472
# 4     51836071  ...         13472
# ..         ...  ...           ...
# 228  149616471  ...         13472
# 229  150687990  ...         13472
# 230  152466582  ...         13472
# 231  154041247  ...         13472
# 232  155509540  ...         13472
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219632  ...         13940
# 1     51494036  ...         13940
# 2     51731577  ...         13940
# 3     51837139  ...         13940
# 4     51837017  ...         13940
# ..         ...  ...           ...
# 228  149568752  ...         13940
# 229  150692585  ...         13940
# 230  152471281  ...         13940
# 231  154045794  ...         13940
# 232  155514310  ...         13940
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219299  ...         13788
# 1     51493522  ...         13788
# 2     51731244  ...         13788
# 3     51836891  ...         13788
# 4     51836738  ...         13788
# ..         ...  ...           ...
# 228  149616601  ...         13788
# 229  150691020  ...         13788
# 230  152469705  ...         13788
# 231  154044265  ...         13788
# 232  155512531  ...         13788
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51491913  ...         13228
# 1     51729526  ...         13228
# 2     51840772  ...         13228
# 3     51835149  ...         13228
# 4     51835327  ...         13228
# ..         ...  ...           ...
# 228  149568762  ...         13228
# 229  150686595  ...         13228
# 230  152465278  ...         13228
# 231  154039718  ...         13228
# 232  155507990  ...         13228
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51731508  ...         13860
# 1     51836877  ...         13860
# 2     51836998  ...         13860
# 3     51842768  ...         13860
# 4     51842959  ...         13860
# ..         ...  ...           ...
# 228  149616495  ...         13860
# 229  150692060  ...         13860
# 230  152470741  ...         13860
# 231  154045317  ...         13860
# 232  155513717  ...         13860
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219866  ...         14056
# 1     51494206  ...         14056
# 2     51731776  ...         14056
# 3     51837463  ...         14056
# 4     51837375  ...         14056
# ..         ...  ...           ...
# 228  149568796  ...         14056
# 229  150693180  ...         14056
# 230  152471876  ...         14056
# 231  154046488  ...         14056
# 232  155515086  ...         14056
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219879  ...         14060
# 1     51494221  ...         14060
# 2     51731792  ...         14060
# 3     51837208  ...         14060
# 4     51837403  ...         14060
# ..         ...  ...           ...
# 228  149616532  ...         14060
# 229  150693205  ...         14060
# 230  152471942  ...         14060
# 231  154046533  ...         14060
# 232  155515144  ...         14060
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51492576  ...         13532
# 1     51730560  ...         13532
# 2     51841557  ...         13532
# 3     51841966  ...         13532
# 4     51841694  ...         13532
# ..         ...  ...           ...
# 228  149616429  ...         13532
# 229  150688364  ...         13532
# 230  152467078  ...         13532
# 231  154041665  ...         13532
# 232  155509961  ...         13532
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219271  ...         13780
# 1     51493500  ...         13780
# 2     51731199  ...         13780
# 3     51836732  ...         13780
# 4     51836924  ...         13780
# ..         ...  ...           ...
# 228  149616555  ...         13780
# 229  150690941  ...         13780
# 230  152469615  ...         13780
# 231  154044137  ...         13780
# 232  155512382  ...         13780
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217692  ...         13348
# 1     51492036  ...         13348
# 2     51729657  ...         13348
# 3     51835521  ...         13348
# 4     51835345  ...         13348
# ..         ...  ...           ...
# 228  149616562  ...         13348
# 229  150687146  ...         13348
# 230  152465651  ...         13348
# 231  154040289  ...         13348
# 232  155508539  ...         13348
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220281  ...         14268
# 1     51494665  ...         14268
# 2     51732351  ...         14268
# 3     51837885  ...         14268
# 4     51837729  ...         14268
# ..         ...  ...           ...
# 213  149616698  ...         14268
# 214  150694670  ...         14268
# 215  152473734  ...         14268
# 216  154048287  ...         14268
# 217  155516601  ...         14268
#
# [218 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51492508  ...         13520
# 1     51838737  ...         13520
# 2     51835959  ...         13520
# 3     51841531  ...         13520
# 4     51841890  ...         13520
# ..         ...  ...           ...
# 228  149616807  ...         13520
# 229  150688323  ...         13520
# 230  152467010  ...         13520
# 231  154041642  ...         13520
# 232  155509942  ...         13520
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51494541  ...         14176
# 1     51837736  ...         14176
# 2     51837518  ...         14176
# 3     51843642  ...         14176
# 4     51843777  ...         14176
# ..         ...  ...           ...
# 228  149616402  ...         14176
# 229  150694103  ...         14176
# 230  152473017  ...         14176
# 231  154047608  ...         14176
# 232  155515920  ...         14176
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51840975  ...         13320
# 1     51835475  ...         13320
# 2     51835307  ...         13320
# 3     51846834  ...         13320
# 4     51846734  ...         13320
# ..         ...  ...           ...
# 228  149616573  ...         13320
# 229  150687037  ...         13320
# 230  152465588  ...         13320
# 231  154040214  ...         13320
# 232  155508416  ...         13320
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51218406  ...         13540
# 1     51492621  ...         13540
# 2     51730570  ...         13540
# 3     51836447  ...         13540
# 4     51836003  ...         13540
# ..         ...  ...           ...
# 227  149616394  ...         13540
# 228  150688395  ...         13540
# 229  152467116  ...         13540
# 230  154041681  ...         13540
# 231  155509968  ...         13540
#
# [232 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217041  ...         12988
# 1     51491345  ...         12988
# 2     51728978  ...         12988
# 3     51834649  ...         12988
# 4     51834937  ...         12988
# ..         ...  ...           ...
# 229  149569011  ...         12988
# 230  150685075  ...         12988
# 231  152464054  ...         12988
# 232  154038305  ...         12988
# 233  155506295  ...         12988
#
# [234 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220203  ...         14236
# 1     51732245  ...         14236
# 2     51837820  ...         14236
# 3     51837869  ...         14236
# 4     51837645  ...         14236
# ..         ...  ...           ...
# 228  149616378  ...         14236
# 229  150694498  ...         14236
# 230  152473561  ...         14236
# 231  154048121  ...         14236
# 232  155516294  ...         14236
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219785  ...         14008
# 1     51494129  ...         14008
# 2     51731690  ...         14008
# 3     51843672  ...         14008
# 4     51837353  ...         14008
# ..         ...  ...           ...
# 228  149615096  ...         14008
# 229  150692998  ...         14008
# 230  152471614  ...         14008
# 231  154046179  ...         14008
# 232  155514871  ...         14008
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51494814  ...         14300
# 1     51732619  ...         14300
# 2     51837799  ...         14300
# 3     51837958  ...         14300
# 4     51843969  ...         14300
# ..         ...  ...           ...
# 216  149568421  ...         14300
# 217  150694971  ...         14300
# 218  152474104  ...         14300
# 219  154048599  ...         14300
# 220  155516886  ...         14300
#
# [221 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493389  ...         13716
# 1     51731017  ...         13716
# 2     51836831  ...         13716
# 3     51836616  ...         13716
# 4     51836750  ...         13716
# ..         ...  ...           ...
# 194  149616363  ...         13716
# 195  150690413  ...         13716
# 196  152469074  ...         13716
# 197  154043587  ...         13716
# 198  155511725  ...         13716
#
# [199 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51217589  ...         13252
# 1    51491942  ...         13252
# 2    51729553  ...         13252
# 3    51835187  ...         13252
# 4    51835366  ...         13252
# ..        ...  ...           ...
# 192  90254927  ...         13252
# 193  91914409  ...         13252
# 194  93150970  ...         13252
# 195  94747193  ...         13252
# 196  96108499  ...         13252
#
# [197 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217759  ...         13388
# 1     51492107  ...         13388
# 2     51729768  ...         13388
# 3     51835680  ...         13388
# 4     51835418  ...         13388
# ..         ...  ...           ...
# 228  149616552  ...         13388
# 229  150687390  ...         13388
# 230  152465940  ...         13388
# 231  154040589  ...         13388
# 232  155508827  ...         13388
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220223  ...         14240
# 1     51732269  ...         14240
# 2     51837661  ...         14240
# 3     51837877  ...         14240
# 4     51844100  ...         14240
# ..         ...  ...           ...
# 193  149616826  ...         14240
# 194  150694520  ...         14240
# 195  152473604  ...         14240
# 196  154048133  ...         14240
# 197  155516401  ...         14240
#
# [198 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51218898  ...         13608
# 1     51493145  ...         13608
# 2     51730783  ...         13608
# 3     51841843  ...         13608
# 4     51853231  ...         13608
# ..         ...  ...           ...
# 192  149616420  ...         13608
# 193  150688930  ...         13608
# 194  152467855  ...         13608
# 195  154042331  ...         13608
# 196  155510550  ...         13608
#
# [197 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493733  ...         13848
# 1     51731461  ...         13848
# 2     51836865  ...         13848
# 3     51837052  ...         13848
# 4     51836982  ...         13848
# ..         ...  ...           ...
# 228  149616848  ...         13848
# 229  150691916  ...         13848
# 230  152470673  ...         13848
# 231  154045237  ...         13848
# 232  155513596  ...         13848
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51495442  ...         14388
# 1     51733010  ...         14388
# 2     51844182  ...         14388
# 3     51838134  ...         14388
# 4     51838037  ...         14388
# ..         ...  ...           ...
# 228  149616798  ...         14388
# 229  150695735  ...         14388
# 230  152474910  ...         14388
# 231  154049485  ...         14388
# 232  155517711  ...         14388
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493765  ...         13868
# 1     51731510  ...         13868
# 2     51836878  ...         13868
# 3     51836999  ...         13868
# 4     51837066  ...         13868
# ..         ...  ...           ...
# 228  149616851  ...         13868
# 229  150692061  ...         13868
# 230  152470747  ...         13868
# 231  154045318  ...         13868
# 232  155513718  ...         13868
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219465  ...         13900
# 1     51493921  ...         13900
# 2     51837079  ...         13900
# 3     51836935  ...         13900
# 4     51837132  ...         13900
# ..         ...  ...           ...
# 228  149616855  ...         13900
# 229  150692287  ...         13900
# 230  152471051  ...         13900
# 231  154045533  ...         13900
# 232  155514016  ...         13900
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220142  ...         14216
# 1     51494602  ...         14216
# 2     51732160  ...         14216
# 3     51837818  ...         14216
# 4     51837587  ...         14216
# ..         ...  ...           ...
# 228  149616674  ...         14216
# 229  150694300  ...         14216
# 230  152473364  ...         14216
# 231  154047902  ...         14216
# 232  155516055  ...         14216
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51837819  ...         14212
# 1     51837589  ...         14212
# 2     51837785  ...         14212
# 3     51843739  ...         14212
# 4     51843832  ...         14212
# ..         ...  ...           ...
# 228  149616675  ...         14212
# 229  150694302  ...         14212
# 230  152473365  ...         14212
# 231  154047903  ...         14212
# 232  155516056  ...         14212
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493856  ...         13888
# 1     51837055  ...         13888
# 2     51837113  ...         13888
# 3     51836914  ...         13888
# 4     51843245  ...         13888
# ..         ...  ...           ...
# 228  149616858  ...         13888
# 229  150692183  ...         13888
# 230  152470966  ...         13888
# 231  154045450  ...         13888
# 232  155513898  ...         13888
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51837976  ...         14356
# 1     51838086  ...         14356
# 2     51838106  ...         14356
# 3     51844137  ...         14356
# 4     51844029  ...         14356
# ..         ...  ...           ...
# 228  149616873  ...         14356
# 229  150695539  ...         14356
# 230  152474654  ...         14356
# 231  154049253  ...         14356
# 232  155517389  ...         14356
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219820  ...         14028
# 1     51731730  ...         14028
# 2     51837324  ...         14028
# 3     51837153  ...         14028
# 4     51837410  ...         14028
# ..         ...  ...           ...
# 228  149616559  ...         14028
# 229  150693043  ...         14028
# 230  152471716  ...         14028
# 231  154046342  ...         14028
# 232  155514997  ...         14028
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51838105  ...         14360
# 1     51838085  ...         14360
# 2     51837974  ...         14360
# 3     51844136  ...         14360
# 4     51844027  ...         14360
# ..         ...  ...           ...
# 228  149616871  ...         14360
# 229  150695538  ...         14360
# 230  152474653  ...         14360
# 231  154049252  ...         14360
# 232  155517388  ...         14360
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51838098  ...         14424
# 1     51844159  ...         14424
# 2     51844280  ...         14424
# 3     51849485  ...         14424
# 4     51849863  ...         14424
# ..         ...  ...           ...
# 228  149616236  ...         14424
# 229  150696058  ...         14424
# 230  152475167  ...         14424
# 231  154049732  ...         14424
# ...
# 0     51217004  ...         12960
# 1     51728919  ...         12960
# 2     51834589  ...         12960
# 3     51834890  ...         12960
# 4     51834885  ...         12960
# ..         ...  ...           ...
# 229  149616843  ...         12960
# 230  150684827  ...         12960
# 231  152463767  ...         12960
# 232  154038083  ...         12960
# 233  155506014  ...         12960
#
# [234 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220497  ...         14412
# 1     51495547  ...         14412
# 2     51733132  ...         14412
# 3     51838071  ...         14412
# 4     51844140  ...         14412
# ..         ...  ...           ...
# 185  149616844  ...         14412
# 186  150695943  ...         14412
# 187  152475025  ...         14412
# 188  154049634  ...         14412
# 189  155517830  ...         14412
#
# [190 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219464  ...         13904
# 1     51493920  ...         13904
# 2     51837131  ...         13904
# 3     51836934  ...         13904
# 4     51837078  ...         13904
# ..         ...  ...           ...
# 228  149616854  ...         13904
# 229  150692285  ...         13904
# 230  152471050  ...         13904
# 231  154045532  ...         13904
# 232  155514015  ...         13904
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220457  ...         14400
# 1     51495519  ...         14400
# 2     51733093  ...         14400
# 3     51838057  ...         14400
# 4     51844122  ...         14400
# ..         ...  ...           ...
# 185  149616845  ...         14400
# 186  150695857  ...         14400
# 187  152475012  ...         14400
# 188  154049569  ...         14400
# 189  155517767  ...         14400
#
# [190 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51495522  ...         14396
# 1     51838058  ...         14396
# 2     51849784  ...         14396
# 3     51860787  ...         14396
# 4     51963433  ...         14396
# ..         ...  ...           ...
# 185  149616846  ...         14396
# 186  150695858  ...         14396
# 187  152475013  ...         14396
# 188  154049570  ...         14396
# 189  155517768  ...         14396
#
# [190 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219395  ...         13876
# 1     51493834  ...         13876
# 2     51837040  ...         13876
# 3     51836906  ...         13876
# 4     51837099  ...         13876
# ..         ...  ...           ...
# 228  149616857  ...         13876
# 229  150692165  ...         13876
# 230  152470915  ...         13876
# 231  154045397  ...         13876
# 232  155513862  ...         13876
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51493734  ...         13844
# 1     51731462  ...         13844
# 2     51836983  ...         13844
# 3     51836866  ...         13844
# 4     51842748  ...         13844
# ..         ...  ...           ...
# 228  149616850  ...         13844
# 229  150691917  ...         13844
# 230  152470674  ...         13844
# 231  154045238  ...         13844
# 232  155513597  ...         13844
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219417  ...         13896
# 1     51493880  ...         13896
# 2     51836922  ...         13896
# 3     51837123  ...         13896
# 4     51837067  ...         13896
# ..         ...  ...           ...
# 228  149616860  ...         13896
# 229  150692222  ...         13896
# 230  152471014  ...         13896
# 231  154045490  ...         13896
# 232  155513941  ...         13896
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220389  ...         14344
# 1     51495241  ...         14344
# 2     51838081  ...         14344
# 3     51838059  ...         14344
# 4     51837930  ...         14344
# ..         ...  ...           ...
# 228  149616852  ...         14344
# 229  150695356  ...         14344
# 230  152474539  ...         14344
# 231  154049109  ...         14344
# 232  155517303  ...         14344
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51219394  ...         13880
# 1     51493825  ...         13880
# 2     51731524  ...         13880
# 3     51843213  ...         13880
# 4     51837039  ...         13880
# ..         ...  ...           ...
# 228  149616856  ...         13880
# 229  150692164  ...         13880
# 230  152470914  ...         13880
# 231  154045396  ...         13880
# 232  155513861  ...         13880
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221840  ...         13884
# 1     51493857  ...         13884
# 2     51733975  ...         13884
# 3     51837114  ...         13884
# 4     51837056  ...         13884
# ..         ...  ...           ...
# 228  149616859  ...         13884
# 229  150692184  ...         13884
# 230  152470967  ...         13884
# 231  154045451  ...         13884
# 232  155513899  ...         13884
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220524  ...         14420
# 1     51495558  ...         14420
# 2     51733157  ...         14420
# 3     51838079  ...         14420
# 4     51838204  ...         14420
# ..         ...  ...           ...
# 228  149616643  ...         14420
# 229  150696003  ...         14420
# 230  152475106  ...         14420
# 231  154049683  ...         14420
# 232  155517855  ...         14420
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51220525  ...         14416
# 1     51495559  ...         14416
# 2     51733158  ...         14416
# 3     51838080  ...         14416
# 4     51838255  ...         14416
# ..         ...  ...           ...
# 228  149616644  ...         14416
# 229  150696004  ...         14416
# 230  152475107  ...         14416
# 231  154049686  ...         14416
# 232  155517856  ...         14416
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51495101  ...         14336
# 1     51838026  ...         14336
# 2     51838046  ...         14336
# 3     51837887  ...         14336
# 4     51843998  ...         14336
# ..         ...  ...           ...
# 228  149616862  ...         14336
# 229  150695262  ...         14336
# 230  152474433  ...         14336
# 231  154048858  ...         14336
# 232  155517221  ...         14336
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221502  ...         14332
# 1     51495102  ...         14332
# 2     51838027  ...         14332
# 3     51837888  ...         14332
# 4     51838047  ...         14332
# ..         ...  ...           ...
# 228  149616863  ...         14332
# 229  150695263  ...         14332
# 230  152474434  ...         14332
# 231  154048865  ...         14332
# 232  155517222  ...         14332
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217699  ...         13356
# 1     51729671  ...         13356
# 2     51841094  ...         13356
# 3     51835518  ...         13356
# 4     51835356  ...         13356
# ..         ...  ...           ...
# 228  149616881  ...         13356
# 229  150687174  ...         13356
# 230  152465689  ...         13356
# 231  154040339  ...         13356
# 232  155508568  ...         13356
#
# [233 rows x 9 columns],       @iot.id  ... ZaehlstelleID
# 0    51839453  ...         14712
# 1    51839384  ...         14712
# 2    51839644  ...         14712
# 3    51845543  ...         14712
# 4    51861787  ...         14712
# ..        ...  ...           ...
# 155  68000867  ...         14712
# 156  54163422  ...         14712
# 157  55188819  ...         14712
# 158  55850544  ...         14712
# 159  57324475  ...         14712
#
# [160 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221619  ...         14664
# 1     51496131  ...         14664
# 2     51733839  ...         14664
# 3     51845055  ...         14664
# 4     51839456  ...         14664
# ..         ...  ...           ...
# 228  149616890  ...         14664
# 229  150698445  ...         14664
# 230  152477663  ...         14664
# 231  154052180  ...         14664
# 232  155520493  ...         14664
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221563  ...         14640
# 1     51496039  ...         14640
# 2     51733760  ...         14640
# 3     51845119  ...         14640
# 4     51838784  ...         14640
# ..         ...  ...           ...
# 228  149616888  ...         14640
# 229  150698153  ...         14640
# 230  152477297  ...         14640
# 231  154051784  ...         14640
# 232  155519997  ...         14640
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217676  ...         13336
# 1     51492026  ...         13336
# 2     51729647  ...         13336
# 3     51835496  ...         13336
# 4     51835332  ...         13336
# ..         ...  ...           ...
# 228  149616894  ...         13336
# 229  150687104  ...         13336
# 230  152465633  ...         13336
# 231  154040258  ...         13336
# 232  155508505  ...         13336
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217700  ...         13352
# 1     51492049  ...         13352
# 2     51841095  ...         13352
# 3     51835357  ...         13352
# 4     51835519  ...         13352
# ..         ...  ...           ...
# 228  149616889  ...         13352
# 229  150687175  ...         13352
# 230  152465690  ...         13352
# 231  154040340  ...         13352
# 232  155508569  ...         13352
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217693  ...         13344
# 1     51492037  ...         13344
# 2     51729658  ...         13344
# 3     51835506  ...         13344
# 4     51835522  ...         13344
# ..         ...  ...           ...
# 228  149616891  ...         13344
# 229  150687147  ...         13344
# 230  152465652  ...         13344
# 231  154040290  ...         13344
# 232  155508540  ...         13344
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221478  ...         14612
# 1     51495938  ...         14612
# 2     51733550  ...         14612
# 3     51838806  ...         14612
# 4     51839129  ...         14612
# ..         ...  ...           ...
# 226  149616893  ...         14612
# 227  150697711  ...         14612
# 228  152476970  ...         14612
# 229  154051466  ...         14612
# 230  155519667  ...         14612
#
# [231 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51221591  ...         14656
# 1     51496099  ...         14656
# 2     51733819  ...         14656
# 3     51839067  ...         14656
# 4     51838876  ...         14656
# ..         ...  ...           ...
# 228  149616895  ...         14656
# 229  150698335  ...         14656
# 230  152477528  ...         14656
# 231  154052064  ...         14656
# 232  155520360  ...         14656
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51218945  ...         13624
# 1     51493170  ...         13624
# 2     51730818  ...         13624
# 3     51841960  ...         13624
# 4     51847678  ...         13624
# ..         ...  ...           ...
# 192  149616903  ...         13624
# 193  150689165  ...         13624
# 194  152467982  ...         13624
# 195  154042479  ...         13624
# 196  155510694  ...         13624
#
# [197 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217709  ...         13364
# 1     51492063  ...         13364
# 2     51729681  ...         13364
# 3     51835364  ...         13364
# 4     51835528  ...         13364
# ..         ...  ...           ...
# 228  149616896  ...         13364
# 229  150687192  ...         13364
# 230  152465703  ...         13364
# 231  154040366  ...         13364
# 232  155508582  ...         13364
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51217710  ...         13360
# 1     51492064  ...         13360
# 2     51729682  ...         13360
# 3     51835572  ...         13360
# 4     51835365  ...         13360
# ..         ...  ...           ...
# 228  149616897  ...         13360
# 229  150687193  ...         13360
# 230  152465704  ...         13360
# 231  154040367  ...         13360
# 232  155508583  ...         13360
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51218170  ...         13504
# 1     51492358  ...         13504
# 2     51730354  ...         13504
# 3     51835876  ...         13504
# 4     51836267  ...         13504
# ..         ...  ...           ...
# 228  149616902  ...         13504
# 229  150688242  ...         13504
# 230  152466907  ...         13504
# 231  154041540  ...         13504
# 232  155509801  ...         13504
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51835484  ...         13328
# 1     51835490  ...         13328
# 2     51835321  ...         13328
# 3     51841059  ...         13328
# 4     51846848  ...         13328
# ..         ...  ...           ...
# 228  149616898  ...         13328
# 229  150687061  ...         13328
# 230  152465614  ...         13328
# 231  154040240  ...         13328
# 232  155508466  ...         13328
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51222286  ...         14868
# 1     51496528  ...         14868
# 2     51734268  ...         14868
# 3     51839902  ...         14868
# 4     51845883  ...         14868
# ..         ...  ...           ...
# 166  135376853  ...         14868
# 167  137070708  ...         14868
# 168  138836042  ...         14868
# 169  140544126  ...         14868
# 170  142243626  ...         14868
#
# [171 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51835469  ...         13312
# 1     51835464  ...         13312
# 2     51835301  ...         13312
# 3     51840957  ...         13312
# 4     51844142  ...         13312
# ..         ...  ...           ...
# 228  149616901  ...         13312
# 229  150687021  ...         13312
# 230  152465557  ...         13312
# 231  154040130  ...         13312
# 232  155508338  ...         13312
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51495304  ...         14372
# 1     51732902  ...         14372
# 2     51844149  ...         14372
# 3     51837994  ...         14372
# 4     51838128  ...         14372
# ..         ...  ...           ...
# 204  149616799  ...         14372
# 205  150695612  ...         14372
# 206  152474729  ...         14372
# 207  154049354  ...         14372
# 208  155517505  ...         14372
#
# [209 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51732903  ...         14368
# 1     51838104  ...         14368
# 2     51837995  ...         14368
# 3     51844312  ...         14368
# 4     51849388  ...         14368
# ..         ...  ...           ...
# 228  149616800  ...         14368
# 229  150695613  ...         14368
# 230  152474730  ...         14368
# 231  154049355  ...         14368
# 232  155517506  ...         14368
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51491470  ...         13024
# 1     51834769  ...         13024
# 2     51835039  ...         13024
# 3     51840370  ...         13024
# 4     51840464  ...         13024
# ..         ...  ...           ...
# 209  114868828  ...         13024
# 210  116630944  ...         13024
# 211  118173053  ...         13024
# 212  119638611  ...         13024
# 213  121313388  ...         13024
#
# [214 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51834740  ...         13016
# 1     51840420  ...         13016
# 2     51840598  ...         13016
# 3     51840353  ...         13016
# 4     51846250  ...         13016
# ..         ...  ...           ...
# 209  114868750  ...         13016
# 210  116630798  ...         13016
# 211  118172936  ...         13016
# 212  119638507  ...         13016
# 213  121313304  ...         13016
#
# [214 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51730977  ...         13692
# 1     51836716  ...         13692
# 2     51836584  ...         13692
# 3     51842221  ...         13692
# 4     51842550  ...         13692
# ..         ...  ...           ...
# 228  149616909  ...         13692
# 229  150690067  ...         13692
# 230  152468770  ...         13692
# 231  154043353  ...         13692
# 232  155511469  ...         13692
#
# [233 rows x 9 columns],        @iot.id  ... ZaehlstelleID
# 0     51222128  ...         14496
# 1     51495675  ...         14496
# 2     51844371  ...         14496
# 3     51838257  ...         14496
# 4     51838444  ...         14496
# ..         ...  ...           ...
# 228  149616136  ...         14496
# 229  150696560  ...         14496
# 230  152475591  ...         14496
# 231  154050099  ...         14496
# 232  155518449  ...         14496
#
# [233 rows x 9 columns]]

# %%
#Convert list to one single dataframe 
DataofAll = pd.concat(ListofAll)

# %%
DataofAll
# Out:
#          @iot.id  ... ZaehlstelleID
# 0     51218835.0  ...         13600
# 1     51493102.0  ...         13600
# 2     51730740.0  ...         13600
# 3     51836486.0  ...         13600
# 4     51836603.0  ...         13600
# ..           ...  ...           ...
# 228  149616136.0  ...         14496
# 229  150696560.0  ...         14496
# 230  152475591.0  ...         14496
# 231  154050099.0  ...         14496
# 232  155518449.0  ...         14496
#
# [107535 rows x 9 columns]

# %% [markdown]
# #Idea to get the coordinates in the dataset.
# - The observations with no coordinates get replaced with [0,0]
# - Question to Philipp: How can we make sure that the coordinates are assigend to the correct Zählstellen?

# %%
coordinatesextract = betterdata["value"]
type(coordinatesextract)

ListofCoordinates = list()

for y in Sequence:
  try:
    #Attention: The next step is wrong, the corresponding IDs must be somehow included, in order to link the coordinates to the correct Zählstellen
    Coordinates = coordinatesextract[y]["observedArea"]["coordinates"]
  except KeyError:
    Coordinates = [0,0]
  ListofCoordinates.append(Coordinates)

# %%
print(ListofCoordinates)
